# %% [markdown]
# 3rd Test - Cane segmentation - Image 2750 - 512x512

# %%
import sys
import os

# Add the project root folder path to sys.path
project_path = '/media/renato/Data/Work/pucpr_pibic_semantic_segmentation/'
sys.path.append(os.path.abspath(project_path))

from dotenv import load_dotenv
from core.validation import get_valid_image_number
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


### Setup ###
# Load variables from .env file
load_dotenv()

# Base Path for image folder
base_mask_folder: str = os.getenv("BASE_MASK_V2_FOLDER")
output_folder: str = os.getenv("OUTPUT_FOLDER")

img_number: str = get_valid_image_number()
mask_path: str = os.path.join(base_mask_folder, f"{img_number}.png")

# Load and Convert Images
bgr_img = cv.imread(mask_path, 1)
hsv_img = cv.cvtColor(bgr_img, cv.COLOR_BGR2HSV)

# %%
# Check shape
print(hsv_img.shape) # Result: (1080, 1920, 3)
# Out:
# (1080, 1920, 3)

# %%
# Preprocess
# Apply blur to reduce noise
hsv_img = cv.GaussianBlur(hsv_img, (5,5), 0)

# %%
# Inspect the actual color values ​​in the image for each pixel
cv.imshow("Inspect Image", hsv_img)
cv.waitKey(0)
cv.destroyAllWindows()

"""
1st Test
Writing down values (Hue, Saturation, Value)
lower_bound = [32, 84, 176]
upper_bound = [60, 156, 187]
"""

"""
2nd Test
Writing down values (Hue, Saturation, Value)
lower_bound = [35, 77, 163]
upper_bound = [72, 163, 214]
"""

"""
3rd Test
Writing down values (Hue, Saturation, Value)
lower_bound = [32, 77, 163]
upper_bound = [72, 163, 214]
"""
# Out:
# '\n3rd Test\nWriting down values (Hue, Saturation, Value)\nlower_bound = [32, 77, 163]\nupper_bound = [72, 163, 214]\n'

# %%
### Process ###
# First Step - Limits
# 1 - Define Cane color limits >> HSV (H:32, S:77, V:163) to (H:72, S:163, V:214)
# New values ​​considering preprocessing
lower_bound = np.array([32, 77, 163]) # Hue, Saturation, Value
upper_bound = np.array([72, 163, 214]) # Hue, Saturation, Value

# Second Step - Binary Mask
# 2.1 - Create mask
mask = cv.inRange(hsv_img, lower_bound, upper_bound)

# 2.2 - Binarize
mask = np.where(mask > 0, 255, 0).astype(np.uint8)
print('Image Before Resize:', mask.shape)

# 2.3 - Visualize binary mask
plt.figure(figsize=[8,8])
plt.imshow(mask, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# Image Before Resize: (1080, 1920)
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
# 2.4 - Check Mask Values
cv.imshow("Inspect Mask", mask)
cv.waitKey(0)
cv.destroyAllWindows()

"""
Values are 0 and 255.
"""
# Out:
# '\nValues are 0 and 255.\n'

# %%
# Morphologic Operation
# 3. Post-processing
kernel = np.ones((3,3), np.uint8) # Better result
mask2 = cv.morphologyEx(mask, cv.MORPH_OPEN, kernel)  # Remove small noise
mask2 = cv.morphologyEx(mask2, cv.MORPH_CLOSE, kernel) # Close small holes


plt.figure(figsize=[8,8])
plt.imshow(mask2, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
# Third Step - Remove Noise
# Find Contours
contours, hierarchy = cv.findContours(mask2, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# Create empty mask
filtered_mask = np.zeros_like(mask2)

# Define minimum area
min_area = 10

# Filter by area and preserve structure
for contour in contours:
    area = cv.contourArea(contour)
    if area >= min_area:
        # Create mask for this specific contour
        temp_mask = np.zeros_like(mask2)
        cv.drawContours(temp_mask, [contour], -1, (255), -1)
        
        # Preserve original pixels within outline
        contour_region = cv.bitwise_and(mask2, temp_mask)
        filtered_mask = cv.bitwise_or(filtered_mask, contour_region)

mask3 = filtered_mask

# 3.4 - Visualize updated mask
plt.figure(figsize=[8,8])
plt.imshow(mask3, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')

"""
Result: Effective on simple objects
Update: After refactor the code now it is possible filter the noise with complex objects

Consider process and min_area as a factor to refactor the image_manipulation.py
"""
# Out:
# '\nResult: Effective on simple objects\nUpdate: After refactor the code now it is possible filter the noise with complex objects\n\nConsider process and min_area as a factor to refactor the image_manipulation.py\n'

# %%
# Check Mask Values again
cv.imshow("Inspect Mask", mask3)
cv.waitKey(0)
cv.destroyAllWindows()

"""
Values are 0 and 255.
"""
# Out:
# '\nValues are 0 and 255.\n'

# %%
# Test: Resize mask and image
mask4a = cv.resize(mask3, (512, 512), interpolation=cv.INTER_NEAREST) # less defined
mask4b = cv.resize(mask3, (512, 512), interpolation=cv.INTER_AREA)    # chosen: cane is better defined
# Re-Binarize
mask4a = np.where(mask4a > 0, 255, 0).astype(np.uint8) 
mask4b = np.where(mask4b > 0, 255, 0).astype(np.uint8) 
print('Image After Resize:', mask4b.shape)

# Setup Plot
plt.figure(figsize=[13,13])
# Plotting mask 4a
plt.subplot(121)
plt.imshow(mask4a, cmap='gray')
plt.title("Resize Interpolation Nearest",fontdict={'fontsize': 25})
plt.axis('off')
# Plotting mask 4b
plt.subplot(122)
plt.imshow(mask4b, cmap='gray')
plt.title("Resize Interpolation Area",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# Image After Resize: (512, 512)
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
# cv.imshow("Inspect Image", bgr_img)
# cv.imshow("Inspect Image", hsv_img)
# cv.imshow("Inspect Image", mask)

# cv.imshow("Inspect Image", mask4a)   # Mask 1 (512x512 - Nearest)
cv.imshow("Inspect Image", mask4b)   # Mask 2 (512x512 - Area)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Visualize Segmentation
bgr_img = cv.resize(bgr_img, (512, 512), interpolation=cv.INTER_AREA)
# Setup Plot
plt.figure(figsize=[8,8])
# Plotting original image
plt.subplot(121)
plt.imshow(bgr_img[:,:,::-1])
plt.title(f"Resized Image nº{img_number}",fontdict={'fontsize': 25})
plt.axis('off')
# Plotting binary mask
plt.subplot(122)
plt.imshow(mask4b, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')

# Applying mask
result = cv.bitwise_and(bgr_img, bgr_img, mask=mask4b)

# Plotting result
plt.figure(figsize=[6,6])
plt.imshow(result[:,:,::-1])
plt.title("Elements of the Image",fontdict={'fontsize':35})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %% [markdown]
# 4th Test - Cane Segmentation - Image 2635 - 512x512

# %%
import sys
import os

# Add the project root folder path to sys.path
project_path = '/media/renato/Data/Work/pucpr_pibic_semantic_segmentation/'
sys.path.append(os.path.abspath(project_path))

from dotenv import load_dotenv
from core.validation import get_valid_image_number
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


### Setup ###
# Load variables from .env file
load_dotenv()

# Base Path for image folder
base_mask_folder: str = os.getenv("BASE_MASK_V2_FOLDER")
output_folder: str = os.getenv("OUTPUT_FOLDER")

img_number: str = get_valid_image_number()
mask_path: str = os.path.join(base_mask_folder, f"{img_number}.png")

# Load and Convert Images
bgr_img = cv.imread(mask_path, 1)
hsv_img = cv.cvtColor(bgr_img, cv.COLOR_BGR2HSV)

# %%
# Inspect the actual color values ​​in the image for each pixel
cv.imshow("Inspect Image", hsv_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Preprocess
# Apply blur to reduce noise
hsv_img = cv.GaussianBlur(hsv_img, (5,5), 0)

# %%
# Inspect the actual color values ​​in the image for each pixel
cv.imshow("Inspect Image", hsv_img)
cv.waitKey(0)
cv.destroyAllWindows()

"""
Writing down values (Hue, Saturation, Value)
lower_bound = [35, 77, 163]
upper_bound = [72, 163, 214]
"""
# Out:
# '\nWriting down values (Hue, Saturation, Value)\nlower_bound = [35, 77, 163]\nupper_bound = [72, 163, 214]\n'

# %%
### Process ###
# First Step - Limits
# 1 - Define Cane color limits >> HSV (H:32, S:77, V:163) to (H:72, S:163, V:214)
# New values ​​considering preprocessing
lower_bound = np.array([32, 77, 163]) # Hue, Saturation, Value
upper_bound = np.array([72, 163, 214]) # Hue, Saturation, Value

# Second Step - Binary Mask
# 2.1 - Create mask
mask = cv.inRange(hsv_img, lower_bound, upper_bound)

# 2.2 - Binarize
mask = np.where(mask > 0, 255, 0).astype(np.uint8)

# 2.3 - Visualize binary mask
plt.figure(figsize=[8,8])
plt.imshow(mask, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
# Inspect the actual color values ​​in the image for each pixel
cv.imshow("Inspect Image", mask)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Morphologic Operation
# 3. Post-processing
kernel = np.ones((3,3), np.uint8)
mask = cv.morphologyEx(mask, cv.MORPH_OPEN, kernel)  # Remove small noise
mask = cv.morphologyEx(mask, cv.MORPH_CLOSE, kernel) # Close small holes

plt.figure(figsize=[8,8])
plt.imshow(mask, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
# Inspect the actual color values ​​in the image for each pixel
cv.imshow("Inspect Image", mask)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np

# Third Step - Remove Noise
# Find Contours
contours, hierarchy = cv.findContours(mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# Create empty mask
filtered_mask = np.zeros_like(mask)

# Define minimum area
min_area = 10

# Filter by area and preserve structure
for contour in contours:
    area = cv.contourArea(contour)
    if area >= min_area:
        # Create mask for this specific contour
        temp_mask = np.zeros_like(mask)
        cv.drawContours(temp_mask, [contour], -1, (255), -1)
        
        # Preserve original pixels within outline
        contour_region = cv.bitwise_and(mask, temp_mask)
        filtered_mask = cv.bitwise_or(filtered_mask, contour_region)

mask = filtered_mask

# 3.4 - Visualize updated mask
plt.figure(figsize=[8,8])
plt.imshow(mask, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
# Test: Resize mask and image
mask1 = cv.resize(mask, (512, 512), interpolation=cv.INTER_NEAREST)
mask2 = cv.resize(mask, (512, 512), interpolation=cv.INTER_AREA) # Better result
# Re-Binarize
mask1 = np.where(mask1 > 0, 255, 0).astype(np.uint8)
mask2 = np.where(mask2 > 0, 255, 0).astype(np.uint8)
print('Image After Resize:', mask2.shape)

# Setup Plot
plt.figure(figsize=[13,13])
# Plotting original image
plt.subplot(121)
plt.imshow(mask1, cmap='gray')
plt.title("Resize Interpolation Nearest",fontdict={'fontsize': 25})
plt.axis('off')
# Plotting binary mask
plt.subplot(122)
plt.imshow(mask2, cmap='gray')
plt.title("Resize Interpolation Area",fontdict={'fontsize': 25})
plt.axis('off')
# Out:
# Image After Resize: (512, 512)
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
# Visualize Segmentation
bgr_img = cv.resize(bgr_img, (512, 512), interpolation=cv.INTER_AREA)
mask = mask2
# Setup Plot
plt.figure(figsize=[8,8])
# Plotting original image
plt.subplot(121)
plt.imshow(bgr_img[:,:,::-1])
plt.title(f"Resized Image nº{img_number}",fontdict={'fontsize': 25})
plt.axis('off')
# Plotting binary mask
plt.subplot(122)
plt.imshow(mask, cmap='gray')
plt.title("Binary Mask",fontdict={'fontsize': 25})
plt.axis('off')

# Applying mask
result = cv.bitwise_and(bgr_img, bgr_img, mask=mask)

# Plotting result
plt.figure(figsize=[6,6])
plt.imshow(result[:,:,::-1])
plt.title("Elements of the Image",fontdict={'fontsize':35})
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))
